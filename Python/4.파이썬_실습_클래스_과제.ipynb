# %% [markdown]
# # 4.1 클래스

# %% [markdown]
# # 과제 1

# %% [markdown]
# #### ./practice/

# %% [markdown]
# ### - 가계부 프로그램 만들기
# ###### - 사용자는 지출 내역을 입력할 수 있고, 내역은 모듈화된 클래스 구조로 관리된다.
# ###### - 날짜, 카테고리, 금액을 사용자에게 반복해서 입력 받는다
# ###### - 금액 입력 시 숫자가 아닌 값이 들어오면 메시지를 출력하고 다시 입력 받는다.
# ###### - "quit" 입력 시 종료, 프로그램 종료 후 모든 지출 내역과 총 지출 금액을 출력한다.

# %%
# 채우기
import Python.practice.account as account
import Python.practice.recode as recode

print("가계부 프로그램 시작!")
try:
    records = input("입력(날짜,카테고리,금액) : ")
    date, category, amount = records.split(',')
    date = int(date)
    category = category
    amount= int(amount)


except ValueError:  #숫자가 아닌 값이 들어오면
    print("숫자를 입력해야 합니다. 다시 입력하세요.")
    pass

finally:
    if records == "quit":
        from .record import record
        get_info()
# Out:
# 가계부 프로그램 시작!
# 입력(날짜,카테고리,금액):  2026-02-01,식비,15000
# 입력(날짜,카테고리,금액):  2026-02-01,교통비,3500
# 입력(날짜,카테고리,금액):  2026-02-02,rlxk,뮻ㅇ
# 숫자를 입력해야 합니다. 다시 입력하세요.
# 입력(날짜,카테고리,금액):  2026-02-02,기타,abcd
# 숫자를 입력해야 합니다. 다시 입력하세요.
# 입력(날짜,카테고리,금액):  quit
# ===== 지출 내역 =====
# 2026-02-01 | 식비 | 15000
# 2026-02-01 | 교통비 | 3500
# ...
#
# 총 지출: 18500원
